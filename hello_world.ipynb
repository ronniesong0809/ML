# %% [markdown]
# <a href="https://colab.research.google.com/github/ronniesong0809/ml-with-python/blob/master/hello_world.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x
import tensorflow.keras as keras
import numpy as np

model = keras.models.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
model.compile(optimizer='sgd', loss='mean_squared_error')
# Out:
# TensorFlow 2.x selected.

# %%
xs = np.array([-1.0, 0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-2.0, 1.0, 4.0, 7.0, 10.0, 13.0], dtype=float)
model.fit(xs, ys, epochs=500)
# Out:
# Train on 6 samples
# Epoch 1/500
# 6/6 [==============================] - 0s 36ms/sample - loss: 41.3394
# Epoch 2/500
# 6/6 [==============================] - 0s 442us/sample - loss: 32.5270
# Epoch 3/500
# 6/6 [==============================] - 0s 289us/sample - loss: 25.5938
# Epoch 4/500
# 6/6 [==============================] - 0s 516us/sample - loss: 20.1390
# Epoch 5/500
# 6/6 [==============================] - 0s 776us/sample - loss: 15.8474
# Epoch 6/500
# 6/6 [==============================] - 0s 600us/sample - loss: 12.4709
# Epoch 7/500
# 6/6 [==============================] - 0s 510us/sample - loss: 9.8143
# Epoch 8/500
# 6/6 [==============================] - 0s 444us/sample - loss: 7.7242
# Epoch 9/500
# 6/6 [==============================] - 0s 461us/sample - loss: 6.0798
# Epoch 10/500
# 6/6 [==============================] - 0s 438us/sample - loss: 4.7860
# Epoch 11/500
# 6/6 [==============================] - 0s 585us/sample - loss: 3.7680
# Epoch 12/500
# ...

# %%
print(model.predict([10.0]))
# Out:
# [[31.002111]]
